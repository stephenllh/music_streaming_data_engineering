# %%
import pandas as pd
import os

# %% [markdown]
# ### Listen events

# %%
parquet_path = "./output/listen_events/month=5/day=3/hour=12"

# %%
os.listdir(parquet_path)
# Out:
# ['.part-00000-c5738d11-554a-4bdd-a3da-1b54b9ad6431.c000.snappy.parquet.crc',
#  '.part-00000-83430e01-56e3-497a-8fea-76fdb5d3a862.c000.snappy.parquet.crc',
#  'part-00000-83430e01-56e3-497a-8fea-76fdb5d3a862.c000.snappy.parquet',
#  'part-00000-c5738d11-554a-4bdd-a3da-1b54b9ad6431.c000.snappy.parquet']

# %%
df = pd.read_parquet(f"{parquet_path}/part-00000-83430e01-56e3-497a-8fea-76fdb5d3a862.c000.snappy.parquet", engine='pyarrow')

# %%
df.head(5).T
# Out:
#                                                                0  \
# artist                                     Pinch feat. Rudey Lee
# song                                                   Step 2 It
# duration                                               260.30975
# ts                                           2022-05-03 12:59:54
# sessionid                                                    NaN
# auth                                                   Logged In
# level                                                       free
# itemInSession                                                  0
# city                                                  Greenville
# zip                                                          NaN
# state                                                         OH
# userAgent      "Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebK...
# lon                                                   -84.650546
# ...

# %% [markdown]
# ### Page view events

# %%
parquet_path = "./output/page_view_events/month=5/day=3/hour=12"
df = pd.read_parquet(f"{parquet_path}/{os.listdir(parquet_path)[-1]}", engine='pyarrow')
